# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

import warnings
warnings.filterwarnings('ignore')

# %%
train_dir='/kaggle/input/egyptian-hieroglyphs/train/'
val_dir='/kaggle/input/egyptian-hieroglyphs/valid/'
test_dir='/kaggle/input/egyptian-hieroglyphs/test/'

train_df=pd.read_csv('/kaggle/input/egyptian-hieroglyphs/train/_annotations.csv')
val_df=pd.read_csv('/kaggle/input/egyptian-hieroglyphs/valid/_annotations.csv')
test_df=pd.read_csv('/kaggle/input/egyptian-hieroglyphs/test/_annotations.csv')

# %%
x_train=[]
y_train=[]


files=train_df['filename']

x_min=train_df['xmin']
x_max=train_df['xmax']
y_min=train_df['ymin']
y_max=train_df['ymax']

i=0

for filename in files:
    image=cv2.imread(os.path.join(train_dir,filename))
    cropped_image=image[y_min[i]:y_max[i],x_min[i]:x_max[i]]
    resized_image=cv2.resize(cropped_image,(224,224))
    rgb_image=cv2.cvtColor(resized_image,cv2.COLOR_BGR2RGB)
    x_train.append(rgb_image)
    i+=1

    
y_train=train_df['class']

# %%
rand_idx=list(np.random.randint(0,len(x_train),20))
plt.figure(figsize=(20,20))
cnt=0
for i in rand_idx:
    plt.subplot(5,5,cnt+1)
    plt.imshow(x_train[i])
    plt.title(y_train[i])
    cnt+=1

# %%
for i in range(len(x_train)):
    x_train[i]=x_train[i]/255.0

# %%
x_val=[]
y_val=val_df['class']

files=val_df['filename']

x_min=val_df['xmin']
x_max=val_df['xmax']
y_min=val_df['ymin']
y_max=val_df['ymax']

i=0

for file in files:
    image=cv2.imread(os.path.join(val_dir,file))
    cropped_image=image[y_min[i]:y_max[i],x_min[i]:x_max[i]]
    resized_image=cv2.resize(cropped_image,(224,224))
    rgb_image=cv2.cvtColor(resized_image,cv2.COLOR_BGR2RGB)
    x_val.append(rgb_image)
    i+=1

# %%
rand_idx=list(np.random.randint(0,len(x_val),20))
plt.figure(figsize=(20,20))
cnt=0
for i in rand_idx:
    plt.subplot(5,5,cnt+1)
    plt.imshow(x_val[i])
    plt.title(y_val[i])
    cnt+=1

# %%
for i in range(len(x_val)):
    x_val[i]=x_val[i]/255.0

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)

# %%
x_train=np.array(x_train)
x_train= x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 3)
y_train=np.array(y_train)
x_val=np.array(x_val)
x_val= x_val.reshape(x_val.shape[0], x_val.shape[1], x_val.shape[2], 3)
y_val=np.array(y_val)

# %%
from sklearn.utils import shuffle
x_train,y_train = shuffle(x_train,y_train)

# %%
input_shape=(224,224,3)
inputs=tf.keras.Input(shape=input_shape)
base_model_3=tf.keras.applications.NASNetMobile(include_top=False,weights='imagenet',input_tensor=inputs)
base_model_3.trainable=True

var=tf.keras.layers.Flatten()(base_model_3.output)

var=tf.keras.layers.Dense(1025,activation='relu')(var)
var=tf.keras.layers.BatchNormalization()(var)
var=tf.keras.layers.Dropout(0.2)(var)

var=tf.keras.layers.Dense(256,activation='relu')(var)
var=tf.keras.layers.BatchNormalization()(var)
var=tf.keras.layers.Dropout(0.2)(var)

var=tf.keras.layers.Dense(256,activation='relu')(var)
var=tf.keras.layers.BatchNormalization()(var)
var=tf.keras.layers.Dropout(0.2)(var)

var=tf.keras.layers.Dense(256,activation='relu')(var)
var=tf.keras.layers.BatchNormalization()(var)
var=tf.keras.layers.Dropout(0.2)(var)

outputs=tf.keras.layers.Dense(95,activation='softmax')(var)

model_3=tf.keras.models.Model(inputs=inputs,outputs=outputs)

opt=tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999)

model_3.compile(loss='sparse_categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model_3.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv1 (Conv2D) │ (None, 111, 111,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn1            │ (None, 111, 111,  │        128 │ stem_conv1[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 111, 111,  │          0 │ stem_bn1[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_conv_1_s… │ (None, 111, 111,  │        352 │ activation[0][0]  │
# │ (Conv2D)            │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_bn_1_ste… │ (None, 111, 111,  │         44 │ reduction_conv_1… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 111, 111,  │          0 │ reduction_bn_1_s… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 111, 111,  │          0 │ stem_bn1[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 115, 115,  │          0 │ activation_1[0][… │
# │ (ZeroPadding2D)     │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 117, 117,  │          0 │ activation_3[0][… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 56, 56,    │        396 │ separable_conv_1… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 56, 56,    │      1,920 │ separable_conv_1… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 56, 56,    │         44 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 56, 56,    │         44 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 56, 56,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 56, 56,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 56, 56,    │        396 │ activation_2[0][… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 56, 56,    │        660 │ activation_4[0][… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 111, 111,  │          0 │ stem_bn1[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 56, 56,    │         44 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 56, 56,    │         44 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 117, 117,  │          0 │ activation_5[0][… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 111, 111,  │          0 │ stem_bn1[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add_1_st… │ (None, 56, 56,    │          0 │ separable_conv_2… │
# │ (Add)               │ 11)               │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 56, 56,    │      1,920 │ separable_conv_1… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 115, 115,  │          0 │ activation_7[0][… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 56, 56,    │          0 │ reduction_add_1_… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 56, 56,    │         44 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 56, 56,    │      1,152 │ separable_conv_1… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 56, 56,    │        220 │ activation_9[0][… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 56, 56,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 56, 56,    │         44 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 56, 56,    │         44 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_pad_1_st… │ (None, 113, 113,  │          0 │ reduction_bn_1_s… │
# │ (ZeroPadding2D)     │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 56, 56,    │        660 │ activation_6[0][… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 56, 56,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 56, 56,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_left2_st… │ (None, 56, 56,    │          0 │ reduction_pad_1_… │
# │ (MaxPooling2D)      │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 56, 56,    │         44 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 56, 56,    │        396 │ activation_8[0][… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 56, 56,    │        220 │ activation_10[0]… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_relu_1_stem… │ (None, 111, 111,  │          0 │ stem_bn1[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add_2_st… │ (None, 56, 56,    │          0 │ reduction_left2_… │
# │ (Add)               │ 11)               │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_left3_st… │ (None, 56, 56,    │          0 │ reduction_pad_1_… │
# │ (AveragePooling2D)  │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 56, 56,    │         44 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_left4_st… │ (None, 56, 56,    │          0 │ reduction_add_1_… │
# │ (AveragePooling2D)  │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 56, 56,    │         44 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_right5_s… │ (None, 56, 56,    │          0 │ reduction_pad_1_… │
# │ (MaxPooling2D)      │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d      │ (None, 112, 112,  │          0 │ adjust_relu_1_st… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add3_ste… │ (None, 56, 56,    │          0 │ reduction_left3_… │
# │ (Add)               │ 11)               │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 56, 56,    │          0 │ reduction_add_2_… │
# │                     │ 11)               │            │ reduction_left4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add4_ste… │ (None, 56, 56,    │          0 │ separable_conv_2… │
# │ (Add)               │ 11)               │            │ reduction_right5… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cropping2d          │ (None, 111, 111,  │          0 │ zero_padding2d[0… │
# │ (Cropping2D)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_concat_s… │ (None, 56, 56,    │          0 │ reduction_add_2_… │
# │ (Concatenate)       │ 44)               │            │ reduction_add3_s… │
# │                     │                   │            │ add[0][0],        │
# │                     │                   │            │ reduction_add4_s… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_avg_pool_1_… │ (None, 56, 56,    │          0 │ adjust_relu_1_st… │
# │ (AveragePooling2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_avg_pool_2_… │ (None, 56, 56,    │          0 │ cropping2d[0][0]  │
# │ (AveragePooling2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 56, 56,    │          0 │ reduction_concat… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_conv_1_stem… │ (None, 56, 56,    │        352 │ adjust_avg_pool_… │
# │ (Conv2D)            │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_conv_2_stem… │ (None, 56, 56,    │        352 │ adjust_avg_pool_… │
# │ (Conv2D)            │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_conv_1_s… │ (None, 56, 56,    │        968 │ activation_11[0]… │
# │ (Conv2D)            │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 56, 56,    │          0 │ adjust_conv_1_st… │
# │ (Concatenate)       │ 22)               │            │ adjust_conv_2_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_bn_1_ste… │ (None, 56, 56,    │         88 │ reduction_conv_1… │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_bn_stem_2    │ (None, 56, 56,    │         88 │ concatenate[0][0] │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 56, 56,    │          0 │ reduction_bn_1_s… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 56, 56,    │          0 │ adjust_bn_stem_2… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 59, 59,    │          0 │ activation_12[0]… │
# │ (ZeroPadding2D)     │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 61, 61,    │          0 │ activation_14[0]… │
# │ (ZeroPadding2D)     │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 28, 28,    │      1,034 │ separable_conv_1… │
# │ (SeparableConv2D)   │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 28, 28,    │      1,562 │ separable_conv_1… │
# │ (SeparableConv2D)   │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │         88 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │         88 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 28, 28,    │      1,034 │ activation_13[0]… │
# │ (SeparableConv2D)   │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 28, 28,    │      1,562 │ activation_15[0]… │
# │ (SeparableConv2D)   │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 56, 56,    │          0 │ adjust_bn_stem_2… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │         88 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │         88 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 61, 61,    │          0 │ activation_16[0]… │
# │ (ZeroPadding2D)     │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 56, 56,    │          0 │ adjust_bn_stem_2… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add_1_st… │ (None, 28, 28,    │          0 │ separable_conv_2… │
# │ (Add)               │ 22)               │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 28, 28,    │      1,562 │ separable_conv_1… │
# │ (SeparableConv2D)   │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 59, 59,    │          0 │ activation_18[0]… │
# │ (ZeroPadding2D)     │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 28, 28,    │          0 │ reduction_add_1_… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │         88 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 28, 28,    │      1,034 │ separable_conv_1… │
# │ (SeparableConv2D)   │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 28, 28,    │        682 │ activation_20[0]… │
# │ (SeparableConv2D)   │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │         88 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │         88 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_pad_1_st… │ (None, 57, 57,    │          0 │ reduction_bn_1_s… │
# │ (ZeroPadding2D)     │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 28, 28,    │      1,562 │ activation_17[0]… │
# │ (SeparableConv2D)   │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_left2_st… │ (None, 28, 28,    │          0 │ reduction_pad_1_… │
# │ (MaxPooling2D)      │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │         88 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 28, 28,    │      1,034 │ activation_19[0]… │
# │ (SeparableConv2D)   │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 28, 28,    │        682 │ activation_21[0]… │
# │ (SeparableConv2D)   │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_relu_1_0     │ (None, 56, 56,    │          0 │ reduction_concat… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add_2_st… │ (None, 28, 28,    │          0 │ reduction_left2_… │
# │ (Add)               │ 22)               │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_left3_st… │ (None, 28, 28,    │          0 │ reduction_pad_1_… │
# │ (AveragePooling2D)  │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │         88 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_left4_st… │ (None, 28, 28,    │          0 │ reduction_add_1_… │
# │ (AveragePooling2D)  │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │         88 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_right5_s… │ (None, 28, 28,    │          0 │ reduction_pad_1_… │
# │ (MaxPooling2D)      │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1    │ (None, 57, 57,    │          0 │ adjust_relu_1_0[… │
# │ (ZeroPadding2D)     │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add3_ste… │ (None, 28, 28,    │          0 │ reduction_left3_… │
# │ (Add)               │ 22)               │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 28, 28,    │          0 │ reduction_add_2_… │
# │                     │ 22)               │            │ reduction_left4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add4_ste… │ (None, 28, 28,    │          0 │ separable_conv_2… │
# │ (Add)               │ 22)               │            │ reduction_right5… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cropping2d_1        │ (None, 56, 56,    │          0 │ zero_padding2d_1… │
# │ (Cropping2D)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_concat_s… │ (None, 28, 28,    │          0 │ reduction_add_2_… │
# │ (Concatenate)       │ 88)               │            │ reduction_add3_s… │
# │                     │                   │            │ add_1[0][0],      │
# │                     │                   │            │ reduction_add4_s… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_avg_pool_1_0 │ (None, 28, 28,    │          0 │ adjust_relu_1_0[… │
# │ (AveragePooling2D)  │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_avg_pool_2_0 │ (None, 28, 28,    │          0 │ cropping2d_1[0][… │
# │ (AveragePooling2D)  │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_conv_1_0     │ (None, 28, 28,    │        968 │ adjust_avg_pool_… │
# │ (Conv2D)            │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_conv_2_0     │ (None, 28, 28,    │        968 │ adjust_avg_pool_… │
# │ (Conv2D)            │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 28, 28,    │          0 │ reduction_concat… │
# │ (Activation)        │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 28, 28,    │          0 │ adjust_conv_1_0[… │
# │ (Concatenate)       │ 44)               │            │ adjust_conv_2_0[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_conv_1_0     │ (None, 28, 28,    │      3,872 │ activation_22[0]… │
# │ (Conv2D)            │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_bn_0         │ (None, 28, 28,    │        176 │ concatenate_1[0]… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_bn_1_0       │ (None, 28, 28,    │        176 │ normal_conv_1_0[… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 28, 28,    │          0 │ normal_bn_1_0[0]… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 28, 28,    │          0 │ adjust_bn_0[0][0] │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 28, 28,    │          0 │ adjust_bn_0[0][0] │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 28, 28,    │          0 │ adjust_bn_0[0][0] │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 28, 28,    │          0 │ normal_bn_1_0[0]… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 28, 28,    │      3,036 │ activation_23[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 28, 28,    │      2,332 │ activation_25[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 28, 28,    │      3,036 │ activation_27[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 28, 28,    │      2,332 │ activation_29[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 28, 28,    │      2,332 │ activation_31[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │        176 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │        176 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │        176 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │        176 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │        176 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 28, 28,    │      3,036 │ activation_24[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 28, 28,    │      2,332 │ activation_26[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 28, 28,    │      3,036 │ activation_28[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 28, 28,    │      2,332 │ activation_30[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 28, 28,    │      2,332 │ activation_32[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │        176 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │        176 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │        176 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │        176 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_left3_0      │ (None, 28, 28,    │          0 │ normal_bn_1_0[0]… │
# │ (AveragePooling2D)  │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_left4_0      │ (None, 28, 28,    │          0 │ adjust_bn_0[0][0] │
# │ (AveragePooling2D)  │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_right4_0     │ (None, 28, 28,    │          0 │ adjust_bn_0[0][0] │
# │ (AveragePooling2D)  │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │        176 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_1_0      │ (None, 28, 28,    │          0 │ separable_conv_2… │
# │ (Add)               │ 44)               │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_2_0      │ (None, 28, 28,    │          0 │ separable_conv_2… │
# │ (Add)               │ 44)               │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_3_0      │ (None, 28, 28,    │          0 │ normal_left3_0[0… │
# │ (Add)               │ 44)               │            │ adjust_bn_0[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_4_0      │ (None, 28, 28,    │          0 │ normal_left4_0[0… │
# │ (Add)               │ 44)               │            │ normal_right4_0[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_5_0      │ (None, 28, 28,    │          0 │ separable_conv_2… │
# │ (Add)               │ 44)               │            │ normal_bn_1_0[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_concat_0     │ (None, 28, 28,    │          0 │ adjust_bn_0[0][0… │
# │ (Concatenate)       │ 264)              │            │ normal_add_1_0[0… │
# │                     │                   │            │ normal_add_2_0[0… │
# │                     │                   │            │ normal_add_3_0[0… │
# │                     │                   │            │ normal_add_4_0[0… │
# │                     │                   │            │ normal_add_5_0[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 28, 28,    │          0 │ reduction_concat… │
# │ (Activation)        │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 28, 28,    │          0 │ normal_concat_0[… │
# │ (Activation)        │ 264)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_conv_projec… │ (None, 28, 28,    │      3,872 │ activation_33[0]… │
# │ (Conv2D)            │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_conv_1_1     │ (None, 28, 28,    │     11,616 │ activation_34[0]… │
# │ (Conv2D)            │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_bn_1         │ (None, 28, 28,    │        176 │ adjust_conv_proj… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_bn_1_1       │ (None, 28, 28,    │        176 │ normal_conv_1_1[… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 28, 28,    │          0 │ normal_bn_1_1[0]… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 28, 28,    │          0 │ adjust_bn_1[0][0] │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 28, 28,    │          0 │ adjust_bn_1[0][0] │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 28, 28,    │          0 │ adjust_bn_1[0][0] │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 28, 28,    │          0 │ normal_bn_1_1[0]… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 28, 28,    │      3,036 │ activation_35[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 28, 28,    │      2,332 │ activation_37[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 28, 28,    │      3,036 │ activation_39[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 28, 28,    │      2,332 │ activation_41[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 28, 28,    │      2,332 │ activation_43[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │        176 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │        176 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │        176 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │        176 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 28, 28,    │        176 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, 28, 28,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 28, 28,    │      3,036 │ activation_36[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 28, 28,    │      2,332 │ activation_38[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 28, 28,    │      3,036 │ activation_40[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 28, 28,    │      2,332 │ activation_42[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 28, 28,    │      2,332 │ activation_44[0]… │
# │ (SeparableConv2D)   │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │        176 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │        176 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │        176 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │        176 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_left3_1      │ (None, 28, 28,    │          0 │ normal_bn_1_1[0]… │
# │ (AveragePooling2D)  │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_left4_1      │ (None, 28, 28,    │          0 │ adjust_bn_1[0][0] │
# │ (AveragePooling2D)  │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_right4_1     │ (None, 28, 28,    │          0 │ adjust_bn_1[0][0] │
# │ (AveragePooling2D)  │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 28, 28,    │        176 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_1_1      │ (None, 28, 28,    │          0 │ separable_conv_2… │
# │ (Add)               │ 44)               │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_2_1      │ (None, 28, 28,    │          0 │ separable_conv_2… │
# │ (Add)               │ 44)               │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_3_1      │ (None, 28, 28,    │          0 │ normal_left3_1[0… │
# │ (Add)               │ 44)               │            │ adjust_bn_1[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_4_1      │ (None, 28, 28,    │          0 │ normal_left4_1[0… │
# │ (Add)               │ 44)               │            │ normal_right4_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_5_1      │ (None, 28, 28,    │          0 │ separable_conv_2… │
# │ (Add)               │ 44)               │            │ normal_bn_1_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_concat_1     │ (None, 28, 28,    │          0 │ adjust_bn_1[0][0… │
# │ (Concatenate)       │ 264)              │            │ normal_add_1_1[0… │
# │                     │                   │            │ normal_add_2_1[0… │
# ...
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_left4_11     │ (None, 7, 7, 176) │          0 │ adjust_bn_11[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_right4_11    │ (None, 7, 7, 176) │          0 │ adjust_bn_11[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 7, 7, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_1_11     │ (None, 7, 7, 176) │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_2_11     │ (None, 7, 7, 176) │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_3_11     │ (None, 7, 7, 176) │          0 │ normal_left3_11[… │
# │ (Add)               │                   │            │ adjust_bn_11[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_4_11     │ (None, 7, 7, 176) │          0 │ normal_left4_11[… │
# │ (Add)               │                   │            │ normal_right4_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_5_11     │ (None, 7, 7, 176) │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ normal_bn_1_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_concat_11    │ (None, 7, 7,      │          0 │ adjust_bn_11[0][… │
# │ (Concatenate)       │ 1056)             │            │ normal_add_1_11[… │
# │                     │                   │            │ normal_add_2_11[… │
# │                     │                   │            │ normal_add_3_11[… │
# │                     │                   │            │ normal_add_4_11[… │
# │                     │                   │            │ normal_add_5_11[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_175      │ (None, 7, 7,      │          0 │ normal_concat_10… │
# │ (Activation)        │ 1056)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_176      │ (None, 7, 7,      │          0 │ normal_concat_11… │
# │ (Activation)        │ 1056)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_conv_projec… │ (None, 7, 7, 176) │    185,856 │ activation_175[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_conv_1_12    │ (None, 7, 7, 176) │    185,856 │ activation_176[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_bn_12        │ (None, 7, 7, 176) │        704 │ adjust_conv_proj… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_bn_1_12      │ (None, 7, 7, 176) │        704 │ normal_conv_1_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_177      │ (None, 7, 7, 176) │          0 │ normal_bn_1_12[0… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_179      │ (None, 7, 7, 176) │          0 │ adjust_bn_12[0][… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_181      │ (None, 7, 7, 176) │          0 │ adjust_bn_12[0][… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_183      │ (None, 7, 7, 176) │          0 │ adjust_bn_12[0][… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_185      │ (None, 7, 7, 176) │          0 │ normal_bn_1_12[0… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 7, 7, 176) │     35,376 │ activation_177[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 7, 7, 176) │     32,560 │ activation_179[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 7, 7, 176) │     35,376 │ activation_181[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 7, 7, 176) │     32,560 │ activation_183[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 7, 7, 176) │     32,560 │ activation_185[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 7, 7, 176) │        704 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 7, 7, 176) │        704 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 7, 7, 176) │        704 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 7, 7, 176) │        704 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 7, 7, 176) │        704 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_178      │ (None, 7, 7, 176) │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_180      │ (None, 7, 7, 176) │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_182      │ (None, 7, 7, 176) │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_184      │ (None, 7, 7, 176) │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_186      │ (None, 7, 7, 176) │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 7, 7, 176) │     35,376 │ activation_178[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 7, 7, 176) │     32,560 │ activation_180[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 7, 7, 176) │     35,376 │ activation_182[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 7, 7, 176) │     32,560 │ activation_184[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 7, 7, 176) │     32,560 │ activation_186[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 7, 7, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 7, 7, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 7, 7, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 7, 7, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_left3_12     │ (None, 7, 7, 176) │          0 │ normal_bn_1_12[0… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_left4_12     │ (None, 7, 7, 176) │          0 │ adjust_bn_12[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_right4_12    │ (None, 7, 7, 176) │          0 │ adjust_bn_12[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 7, 7, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_1_12     │ (None, 7, 7, 176) │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_2_12     │ (None, 7, 7, 176) │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_3_12     │ (None, 7, 7, 176) │          0 │ normal_left3_12[… │
# │ (Add)               │                   │            │ adjust_bn_12[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_4_12     │ (None, 7, 7, 176) │          0 │ normal_left4_12[… │
# │ (Add)               │                   │            │ normal_right4_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_5_12     │ (None, 7, 7, 176) │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ normal_bn_1_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_concat_12    │ (None, 7, 7,      │          0 │ adjust_bn_12[0][… │
# │ (Concatenate)       │ 1056)             │            │ normal_add_1_12[… │
# │                     │                   │            │ normal_add_2_12[… │
# │                     │                   │            │ normal_add_3_12[… │
# │                     │                   │            │ normal_add_4_12[… │
# │                     │                   │            │ normal_add_5_12[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_187      │ (None, 7, 7,      │          0 │ normal_concat_12… │
# │ (Activation)        │ 1056)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 51744)     │          0 │ activation_187[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1025)      │ 53,038,625 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 1025)      │      4,100 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1025)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    262,656 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │     65,792 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │     65,792 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 95)        │     24,415 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 57,734,168 (220.24 MB)
#  Trainable params: 57,693,844 (220.08 MB)
#  Non-trainable params: 40,324 (157.52 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint

early_stopping=EarlyStopping(monitor='val_loss',patience=10,restore_best_weights=True)
learning_rate=ReduceLROnPlateau(monitor='val_loss',factor=0.1,min_lr=1e-6,patience=10)
ckeck_points=ModelCheckpoint(filepath='best_model.keras',monitor='val_loss',save_best_only=True,save_weights_only=False)

# %%
history_3=model_3.fit(x_train,y_train,epochs=50,batch_size=32,validation_data=(x_val,y_val),callbacks=[early_stopping,learning_rate,ckeck_points],shuffle=True)
# Out:
# Epoch 1/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 21s 249ms/step - accuracy: 0.8405 - loss: 0.7979 - val_accuracy: 0.0990 - val_loss: 3.8989 - learning_rate: 1.0000e-04
# Epoch 2/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 229ms/step - accuracy: 0.9126 - loss: 0.5027 - val_accuracy: 0.1080 - val_loss: 3.8614 - learning_rate: 1.0000e-04
# Epoch 3/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 230ms/step - accuracy: 0.9331 - loss: 0.3801 - val_accuracy: 0.1234 - val_loss: 3.8571 - learning_rate: 1.0000e-04
# Epoch 4/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 229ms/step - accuracy: 0.9429 - loss: 0.3342 - val_accuracy: 0.1105 - val_loss: 3.9575 - learning_rate: 1.0000e-04
# Epoch 5/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 230ms/step - accuracy: 0.9562 - loss: 0.2718 - val_accuracy: 0.1183 - val_loss: 3.8983 - learning_rate: 1.0000e-04
# Epoch 6/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 293ms/step - accuracy: 0.9457 - loss: 0.3007 - val_accuracy: 0.1504 - val_loss: 3.8407 - learning_rate: 1.0000e-04
# Epoch 7/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 293ms/step - accuracy: 0.9400 - loss: 0.3126 - val_accuracy: 0.1928 - val_loss: 3.6175 - learning_rate: 1.0000e-04
# Epoch 8/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 295ms/step - accuracy: 0.9298 - loss: 0.3530 - val_accuracy: 0.2378 - val_loss: 3.4486 - learning_rate: 1.0000e-04
# Epoch 9/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 295ms/step - accuracy: 0.9645 - loss: 0.2423 - val_accuracy: 0.3098 - val_loss: 3.1237 - learning_rate: 1.0000e-04
# Epoch 10/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 296ms/step - accuracy: 0.9626 - loss: 0.2126 - val_accuracy: 0.3458 - val_loss: 2.9310 - learning_rate: 1.0000e-04
# Epoch 11/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 30s 351ms/step - accuracy: 0.9665 - loss: 0.1949 - val_accuracy: 0.3843 - val_loss: 2.8219 - learning_rate: 1.0000e-04
# Epoch 12/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 294ms/step - accuracy: 0.9713 - loss: 0.1617 - val_accuracy: 0.3843 - val_loss: 2.6718 - learning_rate: 1.0000e-04
# Epoch 13/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 293ms/step - accuracy: 0.9585 - loss: 0.1877 - val_accuracy: 0.3959 - val_loss: 2.5442 - learning_rate: 1.0000e-04
# Epoch 14/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.9609 - loss: 0.1865 - val_accuracy: 0.3535 - val_loss: 2.6489 - learning_rate: 1.0000e-04
# Epoch 15/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 293ms/step - accuracy: 0.9705 - loss: 0.1520 - val_accuracy: 0.4010 - val_loss: 2.4630 - learning_rate: 1.0000e-04
# Epoch 16/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 289ms/step - accuracy: 0.9714 - loss: 0.1366 - val_accuracy: 0.4254 - val_loss: 2.3952 - learning_rate: 1.0000e-04
# Epoch 17/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 292ms/step - accuracy: 0.9698 - loss: 0.1366 - val_accuracy: 0.4589 - val_loss: 2.2097 - learning_rate: 1.0000e-04
# Epoch 18/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 292ms/step - accuracy: 0.9815 - loss: 0.1158 - val_accuracy: 0.5501 - val_loss: 1.9439 - learning_rate: 1.0000e-04
# Epoch 19/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 294ms/step - accuracy: 0.9723 - loss: 0.1361 - val_accuracy: 0.5925 - val_loss: 1.8185 - learning_rate: 1.0000e-04
# Epoch 20/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 292ms/step - accuracy: 0.9767 - loss: 0.1183 - val_accuracy: 0.5835 - val_loss: 1.8173 - learning_rate: 1.0000e-04
# Epoch 21/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 289ms/step - accuracy: 0.9687 - loss: 0.1270 - val_accuracy: 0.5656 - val_loss: 1.7188 - learning_rate: 1.0000e-04
# Epoch 22/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 292ms/step - accuracy: 0.9679 - loss: 0.1382 - val_accuracy: 0.6067 - val_loss: 1.6240 - learning_rate: 1.0000e-04
# Epoch 23/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 290ms/step - accuracy: 0.9707 - loss: 0.1237 - val_accuracy: 0.6748 - val_loss: 1.3681 - learning_rate: 1.0000e-04
# Epoch 24/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.9712 - loss: 0.1365 - val_accuracy: 0.6183 - val_loss: 1.4830 - learning_rate: 1.0000e-04
# Epoch 25/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 293ms/step - accuracy: 0.9700 - loss: 0.1144 - val_accuracy: 0.6427 - val_loss: 1.3397 - learning_rate: 1.0000e-04
# Epoch 26/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.9599 - loss: 0.1619 - val_accuracy: 0.6375 - val_loss: 1.4722 - learning_rate: 1.0000e-04
# Epoch 27/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 232ms/step - accuracy: 0.9655 - loss: 0.1580 - val_accuracy: 0.6465 - val_loss: 1.4338 - learning_rate: 1.0000e-04
# Epoch 28/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 291ms/step - accuracy: 0.9744 - loss: 0.1243 - val_accuracy: 0.6915 - val_loss: 1.2875 - learning_rate: 1.0000e-04
# Epoch 29/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 292ms/step - accuracy: 0.9714 - loss: 0.1393 - val_accuracy: 0.6748 - val_loss: 1.2825 - learning_rate: 1.0000e-04
# Epoch 30/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 289ms/step - accuracy: 0.9760 - loss: 0.1213 - val_accuracy: 0.7082 - val_loss: 1.1916 - learning_rate: 1.0000e-04
# Epoch 31/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 26s 304ms/step - accuracy: 0.9767 - loss: 0.1143 - val_accuracy: 0.7314 - val_loss: 1.1440 - learning_rate: 1.0000e-04
# Epoch 32/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 290ms/step - accuracy: 0.9821 - loss: 0.1044 - val_accuracy: 0.7751 - val_loss: 0.9512 - learning_rate: 1.0000e-04
# Epoch 33/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 292ms/step - accuracy: 0.9823 - loss: 0.0920 - val_accuracy: 0.7853 - val_loss: 0.8454 - learning_rate: 1.0000e-04
# Epoch 34/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.9599 - loss: 0.1687 - val_accuracy: 0.7224 - val_loss: 1.0957 - learning_rate: 1.0000e-04
# Epoch 35/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 230ms/step - accuracy: 0.9757 - loss: 0.1143 - val_accuracy: 0.7057 - val_loss: 1.1324 - learning_rate: 1.0000e-04
# Epoch 36/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 232ms/step - accuracy: 0.9713 - loss: 0.1148 - val_accuracy: 0.7416 - val_loss: 1.0394 - learning_rate: 1.0000e-04
# Epoch 37/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.9652 - loss: 0.1334 - val_accuracy: 0.7494 - val_loss: 0.9276 - learning_rate: 1.0000e-04
# Epoch 38/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 291ms/step - accuracy: 0.9818 - loss: 0.0999 - val_accuracy: 0.7853 - val_loss: 0.8034 - learning_rate: 1.0000e-04
# Epoch 39/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.9667 - loss: 0.1554 - val_accuracy: 0.7725 - val_loss: 0.8945 - learning_rate: 1.0000e-04
# Epoch 40/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.9549 - loss: 0.1605 - val_accuracy: 0.6761 - val_loss: 1.1885 - learning_rate: 1.0000e-04
# Epoch 41/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 232ms/step - accuracy: 0.9692 - loss: 0.1238 - val_accuracy: 0.7519 - val_loss: 0.9083 - learning_rate: 1.0000e-04
# Epoch 42/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 23s 265ms/step - accuracy: 0.9692 - loss: 0.1230 - val_accuracy: 0.7249 - val_loss: 1.0625 - learning_rate: 1.0000e-04
# Epoch 43/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 232ms/step - accuracy: 0.9441 - loss: 0.1939 - val_accuracy: 0.7159 - val_loss: 1.0800 - learning_rate: 1.0000e-04
# Epoch 44/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 230ms/step - accuracy: 0.9714 - loss: 0.1178 - val_accuracy: 0.7584 - val_loss: 0.9654 - learning_rate: 1.0000e-04
# Epoch 45/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 25s 293ms/step - accuracy: 0.9658 - loss: 0.1318 - val_accuracy: 0.7905 - val_loss: 0.8003 - learning_rate: 1.0000e-04
# Epoch 46/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.9644 - loss: 0.1350 - val_accuracy: 0.7712 - val_loss: 0.8876 - learning_rate: 1.0000e-04
# Epoch 47/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.9758 - loss: 0.1042 - val_accuracy: 0.7481 - val_loss: 0.9113 - learning_rate: 1.0000e-04
# Epoch 48/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.9726 - loss: 0.0992 - val_accuracy: 0.7712 - val_loss: 0.8115 - learning_rate: 1.0000e-04
# Epoch 49/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 230ms/step - accuracy: 0.9780 - loss: 0.0964 - val_accuracy: 0.7159 - val_loss: 1.0625 - learning_rate: 1.0000e-04
# Epoch 50/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.9786 - loss: 0.0960 - val_accuracy: 0.7455 - val_loss: 0.9144 - learning_rate: 1.0000e-04

# %%
acc = history_3.history['accuracy']
val_acc = history_3.history['val_accuracy']

loss = history_3.history['loss']
val_loss = history_3.history['val_loss']

epochs = range(1, len(loss) + 1)

# %%
#accuracy plot
plt.plot(epochs, acc, color='green', label='Training Accuracy')
plt.plot(epochs, val_acc, color='blue', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.ylim(0,1.02)
plt.show()

# %%
plt.figure()
#loss plot
plt.plot(epochs, loss, color='green', label='Training Loss')
plt.plot(epochs, val_loss, color='red', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.ylim(0,1.02)
plt.show()

# %%
# Evaluate the model
model_evaluate = model_3.evaluate(x_train,y_train)
print("Loss     : ",model_evaluate[0])
print("Accuracy : ",model_evaluate[1])
# Out:
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.7926 - loss: 0.7732
# Loss     :  0.7884153723716736
# Accuracy :  0.7936099767684937

# %%
# Evaluate the model
model_evaluate = model_3.evaluate(x_val,y_val)
print("Loss     : ",model_evaluate[0])
print("Accuracy : ",model_evaluate[1])
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7868 - loss: 0.8420
# Loss     :  0.800300121307373
# Accuracy :  0.7904884219169617

# %%
x_test=[]
y_test=[]


files=test_df['filename']

x_min=test_df['xmin']
x_max=test_df['xmax']
y_min=test_df['ymin']
y_max=test_df['ymax']

i=0

for filename in files:
    image=cv2.imread(os.path.join(test_dir,filename))
    cropped_image=image[y_min[i]:y_max[i],x_min[i]:x_max[i]]
    resized_image=cv2.resize(cropped_image,(224,224))
    rgb_image=cv2.cvtColor(resized_image,cv2.COLOR_BGR2RGB)
    x_test.append(rgb_image)
    i+=1

    
y_test=test_df['class']

# %%
for i in range(len(x_test)):
    x_test[i]=x_test[i]/255.0
    
y_test = label_encoder.transform(y_test)

# %%
x_test=np.array(x_test)
x_test= x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 3)
y_test=np.array(y_test)

# %%
model_evaluate = model_3.evaluate(x_test,y_test)
print("Loss     : ",model_evaluate[0])
print("Accuracy : ",model_evaluate[1])
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7876 - loss: 0.7523
# Loss     :  0.812210738658905
# Accuracy :  0.7712082266807556

# %%
predictions = model_3.predict(x_test)
y_pred = predictions.argmax(axis=-1)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step

# %%
from sklearn.metrics import classification_report
print("Classification report : \n",classification_report(y_test, y_pred))
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         2
#            4       0.80      0.67      0.73         6
#            5       0.50      1.00      0.67         3
#            6       1.00      1.00      1.00         6
#            7       0.33      1.00      0.50         1
#            8       1.00      0.86      0.92         7
#            9       1.00      1.00      1.00         8
#           10       0.75      0.60      0.67         5
#           11       1.00      1.00      1.00         3
#           12       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         1
#           14       0.33      1.00      0.50         3
#           15       0.67      1.00      0.80         2
#           16       1.00      1.00      1.00         2
#           17       1.00      0.83      0.91         6
#           18       1.00      1.00      1.00         3
#           19       0.25      1.00      0.40         2
#           20       0.50      1.00      0.67         1
#           21       1.00      0.33      0.50         3
#           22       1.00      1.00      1.00         8
#           23       1.00      0.50      0.67         2
#           24       1.00      0.75      0.86         8
#           25       1.00      1.00      1.00         3
#           26       1.00      1.00      1.00         3
#           27       0.33      1.00      0.50         1
#           28       0.00      0.00      0.00         1
#           29       0.31      1.00      0.47         4
#           30       0.12      1.00      0.22         2
#           31       0.86      1.00      0.92         6
#           32       1.00      1.00      1.00         3
#           33       0.29      0.67      0.40         3
#           34       0.86      0.86      0.86         7
#           35       0.36      1.00      0.53         4
#           36       0.80      0.80      0.80         5
#           37       1.00      0.25      0.40         8
#           38       0.00      0.00      0.00         6
#           39       1.00      0.12      0.22         8
#           40       1.00      1.00      1.00         6
#           41       0.00      0.00      0.00         4
#           42       1.00      1.00      1.00         4
#           43       0.80      0.80      0.80         5
#           44       0.83      0.83      0.83         6
#           45       1.00      0.50      0.67         4
#           46       0.25      0.67      0.36         3
#           47       0.80      1.00      0.89         4
#           48       1.00      1.00      1.00         2
#           49       0.67      0.50      0.57         4
#           50       1.00      0.75      0.86         4
#           51       1.00      1.00      1.00         3
#           52       1.00      0.33      0.50         6
#           53       1.00      0.86      0.92         7
#           54       0.50      1.00      0.67         3
#           56       0.38      1.00      0.55         3
#           57       0.00      0.00      0.00         1
#           58       1.00      0.60      0.75         5
#           59       1.00      0.50      0.67         2
#           60       1.00      0.25      0.40         4
#           61       1.00      1.00      1.00         3
#           62       1.00      0.50      0.67         2
#           63       0.75      1.00      0.86         3
#           64       0.00      0.00      0.00         2
#           65       1.00      0.50      0.67         2
#           66       1.00      0.50      0.67        10
#           67       1.00      0.50      0.67         4
#           68       0.75      1.00      0.86         6
#           69       1.00      0.80      0.89         5
#           70       1.00      1.00      1.00         2
#           71       1.00      0.33      0.50         6
#           72       1.00      1.00      1.00         1
#           73       1.00      1.00      1.00         5
#           74       0.80      1.00      0.89         4
#           75       1.00      1.00      1.00         6
#           76       1.00      1.00      1.00         6
#           77       1.00      1.00      1.00         5
#           78       1.00      1.00      1.00         4
#           79       1.00      1.00      1.00         6
#           80       1.00      1.00      1.00         4
#           81       0.83      0.83      0.83         6
#           82       1.00      1.00      1.00         4
#           83       1.00      0.40      0.57         5
#           84       0.00      0.00      0.00         3
#           85       1.00      1.00      1.00         4
#           86       1.00      1.00      1.00         8
#           87       1.00      1.00      1.00         4
#           88       1.00      1.00      1.00         4
#           89       1.00      1.00      1.00         5
#           90       0.88      1.00      0.93         7
#           91       0.00      0.00      0.00         1
#           92       1.00      1.00      1.00         3
#           93       0.75      1.00      0.86         3
#           94       0.00      0.00      0.00         5
#
#     accuracy                           0.77       389
#    macro avg       0.77      0.76      0.72       389
# weighted avg       0.84      0.77      0.76       389
